# %% [markdown]
# ## Riot Games API Scrapping

# %% [markdown]
# ### Import des librairies

# %%
import requests
from datetime import datetime

# %% [markdown]
# ### Appel de l'API

# %%
api_key = "RGAPI-6439fe6f-9e4c-4887-aac5-5c1aff6b8f6b"

# %%
platform_api = ["BR1", "EUN1", "EUW1", "JP1", "KR", "LA1", "LA2", "NA1", "OC1", "TR1", "RU", "PH2", "SG2", "TH2", "TW2", "VN2"]

# %%
region_api = ["americas", "asia", "europe", "sea"]

# %%
tagLine = "ImYou"
gameName = "Cig"

# %%
api_url = "https://{}.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{}/{}?api_key={}".format(region_api[2], gameName, tagLine, api_key)
api_url
# Out:
# 'https://europe.api.riotgames.com/riot/account/v1/accounts/by-riot-id/Cig/ImYou?api_key=RGAPI-6439fe6f-9e4c-4887-aac5-5c1aff6b8f6b'

# %%
response = requests.get(api_url)
response
# Out:
# <Response [200]>

# %%
player_info = response.json()
player_info
# Out:
# {'puuid': 'NxF40SY_mttmXpCbFgqzcQhy13X9g2c3E8UiOe9_ipM3Lj6r4vv2hLoi5YVt3s5cNcCLKZsFyCroAg',
#  'gameName': 'Cig',
#  'tagLine': 'ImYou'}

# %%
puuid = player_info['puuid']

# %%
start = 0
count = 20

# %%
api_url_match = "https://{}.api.riotgames.com/lol/match/v5/matches/by-puuid/{}/ids?start={}&count={}&startTime=1705705200&endTime=1706569200&api_key={}".format(region_api[2], puuid, start, count, api_key)

# %%
response = requests.get(api_url_match)
response
# Out:
# <Response [200]>

# %%
match_list = response.json()
match_list
# Out:
# ['EUW1_6790274039',
#  'EUW1_6789169772',
#  'EUW1_6788014722',
#  'EUW1_6787893417',
#  'EUW1_6786317002',
#  'EUW1_6785867530',
#  'EUW1_6785815443',
#  'EUW1_6785765295',
#  'EUW1_6785736084',
#  'EUW1_6776291209']

# %% [markdown]
# ### Premier match

# %%
match_list[0]
# Out:
# 'EUW1_6790274039'

# %%
matchlist0_api_url = "https://{}.api.riotgames.com/lol/match/v5/matches/{}?api_key={}".format(region_api[2], match_list[0], api_key) # matchlist[0] est le premier match de la liste

# %%
response = requests.get(matchlist0_api_url)
response
# Out:
# <Response [200]>

# %%
match0_info = response.json()
match0_info
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'EUW1_6790274039',
#   'participants': ['KKf9xN-HwONiM_YFpp4jYTjw-p5rOxwINmG3ZKYiw_Hq58PHmajzy9H5IzTsWb_LV-owXuYlPZmHbA',
#    'VL5ZWNTpGu8wwYjUmeFNKKk83AYZIKZ4WJOCY66jsnKR2ugGVWzSpbjOIo4AtXlcumnQ6CirxZv6PQ',
#    'oRZb_Rypsej_DSHGCXnpnpNEvUi9hEXLi71zvNDXUg096ZwfUKtzHWbiVo1sRtLRZHVU4zTY2AKluw',
#    'EOH2TDJU1PGeGJ4d8VHyD4A6TlwIkbDDNKO8cy0qowUT4umc2DJ1YFdoDWPO_x8lKiQh3us1LJGDmQ',
#    'Tz2N4jLd6pbluUSjCOUFG6gDF4PYk2r5tagn2sbLwVnRw1akAoBoWmGznWS_N4qqAljyXRw1CweasQ',
#    'NxF40SY_mttmXpCbFgqzcQhy13X9g2c3E8UiOe9_ipM3Lj6r4vv2hLoi5YVt3s5cNcCLKZsFyCroAg',
#    'iYF6aIN4DvvouoXpAfVtPFXGEuIjHw2wmTkY6HDEijPIYyqbfTrUEsFPUlEXeaMsKLv_qrUSlAWoGw',
#    'tRKSZ7RyXM3JOVFDT0bNGUFAuyevCwdMJgvaEzlskANUcXp0QzT8eaXWZJwWjXrVidEX3xJ1w4-uuw',
#    'W4EyJCnzMdqD-OYHdFI8cWgZHo5ra4Gjay2e6DnKjZ6wo7eXwcSG2_6k6NUNMJL9IsJQLwu5H6xDGQ',
#    'zgvaE6ydls9WRNgAdF0vpVz0y6kVmUk6fmb4Y5OS062zVbNPbdXfAdm-UWhncfhyqQXyHM7UOe6pKw']},
# ...

# %%
part_index = match0_info["metadata"]["participants"].index(puuid)
part_index
# Out:
# 5

# %%
match0_info["info"]["participants"][part_index]["summonerName"]
# Out:
# 'Cigt'

# %%
timestamp = match0_info["info"]["gameCreation"] / 1000  # Convert milliseconds to seconds
date = datetime.utcfromtimestamp(timestamp).strftime('%d/%m/%Y')  # Convert timestamp to date string
date
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_3632\3888285901.py:2: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   date = datetime.utcfromtimestamp(timestamp).strftime('%d/%m/%Y')  # Convert timestamp to date string
# '29/01/2024'

# %%
match0_info["info"]["participants"][part_index]["championName"]
# Out:
# 'Akali'

# %% [markdown]
# ### Statistiques
